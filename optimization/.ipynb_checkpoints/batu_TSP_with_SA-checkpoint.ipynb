# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import googlemaps
import random
from datetime import datetime

locations = ["Emirgan Korusu","Turkcell Kucukyali","Orjin Maslak","Levent Loft"]
#locations = random.shuffle(locations)
gmaps = googlemaps.Client(key='AIzaSyBFbrjZ60wcVQ3vil3BSh-dw4FjZsbC7R4')
now = datetime.now()

matrix_result = gmaps.distance_matrix(locations, locations, mode="driving", departure_time=now)
matrix_size = len(matrix_result['rows'][0]['elements'])
matrix_list = []
matrix_array = []
matrix_list_integers = []

def matrix_search (x,y):
    return matrix_result['rows'][x]['elements'][y]['distance']['text']

for i in range(matrix_size):
    for j in range(matrix_size):
        result = matrix_search(i,j)
        matrix_list.append(result)
        
for i in range(len(matrix_list)):
    value = matrix_list[i].split()
    if value[1] == 'km':
        matrix_list_integers.append(float(value[0])*1000)
    else:
        matrix_list_integers.append(float((value[0])))

matrix_array = np.array(matrix_list_integers).reshape((4,4))
df = pd.DataFrame(matrix_array, columns=locations, index=locations)

Data1 = df
X0 = locations

Distances = []
t = 0

for i in range(len(X0)-1):
    X1 = Data1.loc[X0[t],X0[t+1]]
    X11 = Data1.loc[X0[-1],X0[0]]
    Distances.append(X1)
    t = t+1
    
Distances.append(X11)
Travel_length = sum(Distances)

print("Your initial route is: ", locations)
print("Length of travel is: ", Travel_length/1000, " km.")

T0 = 3000
M = 1000
N = 50
Alpha = 0.85

Temp = []
Min_Distance = []

for i in range(M):
    for j in range(N):
        Rand1 = np.random.randint(0,len(X0))
        Rand2 = np.random.randint(0,len(X0))
        while Rand1 == Rand2:
            Rand2 = np.random.randint(0,len(X0))
            
        Xtemp = []
        A1 = X0[Rand1]
        A2 = X0[Rand2]
        w = 0
        
        for i in X0:
            if X0[w] == A1:
                Xtemp = np.append(Xtemp, A2)
            elif X0[w] == A2:
                Xtemp = np.append(Xtemp, A1)
            else:
                Xtemp = np.append(Xtemp, X0[w])
            w = w+1
            
        Xtemp = list(Xtemp)
        
        Distances_X0 = []
        t = 0
        
        for i in range(len(X0)-1):
            X1_1 = Data1.loc[X0[t],X0[t+1]]
            X11 = Data1.loc[X0[-1],X0[0]]
            Distances_X0.append(X1_1)
            t = t+1
            
        Distances_X0.append(X11)
        Len_X0 = sum(Distances_X0)
        
        Distances_Xtemp = []
        t = 0
        
        for i in range(len(Xtemp)-1):
            X1_2 = Data1.loc[Xtemp[t],Xtemp[t+1]]
            X11 = Data1.loc[Xtemp[-1],Xtemp[0]]
            Distances_Xtemp.append(X1_2)
            t = t+1
        
        Distances_Xtemp.append(X11)
        Len_Xtemp = sum(Distances_Xtemp)
        
        formula = 1 / (np.exp((Len_Xtemp-Len_X0)/T0))
        rand_num = np.random.rand()
        
        if Len_Xtemp <= Len_X0:
            X0 = Xtemp
        elif rand_num <= formula:
            X0 = Xtemp
        else:
            X0 = X0
            
        T0 = Alpha * T0
        
print("Final solution:", X0)
print("Final distance:", Len_X0/1000, " km.")
# Out:
# Your initial route is:  ['Emirgan Korusu', 'Turkcell Kucukyali', 'Orjin Maslak', 'Levent Loft']
# Length of travel is:  68.3  km.
# /home/batu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:110: RuntimeWarning: overflow encountered in exp
# Final solution: ['Levent Loft', 'Turkcell Kucukyali', 'Emirgan Korusu', 'Orjin Maslak']
# Final distance: 53.3  km.
# /home/batu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:110: RuntimeWarning: overflow encountered in double_scalars
