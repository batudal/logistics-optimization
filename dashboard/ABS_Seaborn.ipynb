# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def load_data(nrows):
    data = pd.read_csv('abs_fixed_data.csv', index_col=1, nrows=nrows)
    return data
data = load_data(31)

#df = pd.read_csv('abs_data.csv', index_col = 1 ,parse_dates=['tarih'])

# %%
def load_data(nrows):
    data = pd.read_csv('abs_fixed_data.csv',nrows=nrows)
    data['tarih'] = pd.to_datetime(data['tarih'])
    return data
data = load_data(31)
data.describe()
# Out:
#         sefer_no   yapilan_km        yakit     feribot  otoban_kopru  \
# count  31.000000    31.000000    25.000000   31.000000          31.0
# mean   18.064516   808.709677  1374.920000  364.193548         338.0
# std     9.208458   194.849890   683.228727   32.328954           0.0
# min     3.000000   247.000000    85.000000  190.000000         338.0
# 25%    10.500000   691.000000   847.000000  370.000000         338.0
# 50%    18.000000   728.000000  1420.000000  370.000000         338.0
# 75%    25.500000   940.000000  1603.000000  370.000000         338.0
# max    35.000000  1249.000000  3305.000000  370.000000         338.0
#
#          harcirah        maas  toplam_fatura  eliner_fatura  abs_komisyon  \
# count   31.000000   31.000000      31.000000      31.000000     31.000000
# mean   235.161290  522.580645    3978.451613    3326.451613    652.000000
# std     44.562388   99.027530     755.191359     560.497091    257.642517
# ...

# %%
plt.hist(data['toplam_fatura'], bins=10)
# Out:
# (array([1., 3., 6., 4., 7., 4., 2., 3., 0., 1.]),
#  array([2500., 2850., 3200., 3550., 3900., 4250., 4600., 4950., 5300.,
#         5650., 6000.]),
#  <a list of 10 Patch objects>)

# %%
data = data.set_index(pd.DatetimeIndex(data['tarih']))

# %%
data.adjusted = []

for x in range(10):
    squares.append(x**2)

for x in range(10)
    str.split

# %%
sns.distplot(data['toplam_fatura'], bins=20)

# %%
data.tail()
# Out:
#                  plaka      tarih  sefer_no  yapilan_km   yakit  feribot  \
# tarih
# 2019-09-22  34 CBT 828 2019-09-22        29         874  3305.0      370
# 2019-09-24  34 CBT 828 2019-09-24        30         682  1393.0      370
# 2019-09-26  34 CBT 828 2019-09-26        31         668     NaN      370
# 2019-09-30  34 CBT 828 2019-09-30        32         807  2292.0      370
# 2019-09-30   31 U 6861 2019-09-30        35         810  1723.0      370
#
#             otoban_kopru  harcirah  maas  toplam_fatura  eliner_fatura  \
# tarih
# 2019-09-22           338       270   600           4100           3200
# 2019-09-24           338       180   400           3950           3300
# 2019-09-26           338       180   400           3500           3000
# 2019-09-30           338       180   400           4550           3600
# 2019-09-30           338       270   600           4000           3200
#
#             abs_komisyon  month
# tarih
# 2019-09-22           900      9
# ...

# %%
data.count().max()
# Out:
# 31

# %%
sns.stripplot(x='toplam_fatura', y='yapilan_km', data=df2, jitter=False, size=10, hue='plaka')

# %%
sns.lmplot(x="net_gelir", y="yapilan_km", col="plaka", hue="plaka", data=df2,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-399-f63f0cee7d48> in <module>
#       1 sns.lmplot(x="net_gelir", y="yapilan_km", col="plaka", hue="plaka", data=df2,
#       2            col_wrap=2, ci=None, palette="muted", height=4,
# ----> 3            scatter_kws={"s": 50, "alpha": 1})
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     549     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     550     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# ...

# %%
df.groupby('month').mean()['yapilan_km'].plot()

# %%
import matplotlib.pyplot as plt

plt.plot( 'tarih', 'toplam_fatura', data=df, marker='', markerfacecolor='blue', color='skyblue', linewidth=2)
plt.plot( 'tarih', 'eliner_fatura', data=df, marker='', color='olive', linewidth=2, label="eliner")
plt.plot( 'tarih', 'abs_komisyon', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="abs")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-400-d04e34bfd35b> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot( 'tarih', 'toplam_fatura', data=df, marker='', markerfacecolor='blue', color='skyblue', linewidth=2)
#       4 plt.plot( 'tarih', 'eliner_fatura', data=df, marker='', color='olive', linewidth=2, label="eliner")
#       5 plt.plot( 'tarih', 'abs_komisyon', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="abs")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(df['tarih'],df['toplam_fatura'], marker='o')
axes.plot(df['tarih'],df['eliner_fatura'], marker='o')
axes.plot(df['tarih'],df['abs_komisyon'], marker='o')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=True,      # ticks along the bottom edge are off
    labelbottom=False) # labels along the bottom edge are off
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tarih'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-401-1aa351eb1079> in <module>
#       3 fig = plt.figure()
# ...

# %%
df['net_gelir'] = df['toplam_fatura']- df['abs_komisyon'] -df['harcirah']-df['duzeltilmis_yakit']-df['maas']-df['otoban_kopru']-df['feribot']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duzeltilmis_yakit'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-403-03fdd4430032> in <module>
# ...

# %%
df.groupby('month').mean()['km_basi'].plot()

# %%
k1 = df.loc['34 CBT 828'][['km_basi','tarih']]
k2 = df.loc['31 U 6861'][['km_basi','tarih']]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(40,6))
axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(k1['tarih'],k1['km_basi'], marker='o', lw=1)
axes.plot(k2['tarih'],k2['km_basi'], marker='o', lw=1)

# %%
# Out:
# 0.1904620860766062
